# %% [markdown]
# ## Lectura de datos desde CSV

# %%
path1 = '/gpfs/fs01/user/s57f-73edb3521eee1d-79e3f294add4/notebook/data2/bloqueo2balanceado.csv'
path2 = '/gpfs/fs01/user/s57f-73edb3521eee1d-79e3f294add4/notebook/data2/unicard2balanceado.csv'
path3 = '/gpfs/fs01/user/s57f-73edb3521eee1d-79e3f294add4/notebook/data2/muestra2desbalanceada.csv'

# %%
import pandas as pd

bloq2bal = pd.read_csv(path1, index_col=False, header=0, sep='\t')
unic2bal = pd.read_csv(path2, index_col=False, header=0, sep='\t')
mues2bal = pd.read_csv(path3, index_col=False, header=0, sep='\t')

# %%
bloq2bal.head()
# Out:
#    CUSTOMER_ID  std_pago_unired  max_pago_unired  avg_pago_unired  \
# 0     14295828     34786.587006           135466     54942.416667
# 1     30174068     22804.835996            97050     50127.857143
# 2     54612656      4587.755442            43850     38700.000000
# 3     99841158     24316.463764            77890     39529.000000
# 4     70026320     28030.667045           104700     63497.000000
#
#    pago_unired_mensual  avg_dia_pago_unired  max_dia_pago_unired  \
# 0               659309             5.089003            10.153817
# 1               350895             5.595878             6.363961
# 2               116100             2.819995             4.932883
# 3               395290            10.563605            10.563605
# 4               317485             9.364604            11.150486
#
#    min_dia_pago_unired  avg_uso_tarjeta  PAYMENT_MEAN_ID   ...    \
# 0             0.707107         0.250000                0   ...
# ...

# %%
unic2bal.head()
# Out:
#    CUSTOMER_ID  std_pago_unired  max_pago_unired  avg_pago_unired  \
# 0     38170206     90870.708796           330864    305661.000000
# 1     97880186     24994.720672           163230     90924.454545
# 2     32599736     27111.064254           138929     86722.583333
# 3     83214884      8026.051333            40250     32300.000000
# 4     75513186     52389.705790           159918     80027.500000
#
#    pago_unired_mensual  avg_dia_pago_unired  max_dia_pago_unired  \
# 0              3973593             2.843120             2.843120
# 1              1000169             7.071835             8.846759
# 2              1040671             5.095258             7.718253
# 3                96900             4.242641             4.242641
# 4               800275             8.837528             9.912114
#
#    min_dia_pago_unired  avg_uso_tarjeta  PAYMENT_MEAN_ID   ...    \
# 0             2.843120         0.275556                1   ...
# ...

# %%
mues2bal = mues2bal.drop_duplicates()
mues2bal = mues2bal.reset_index(drop=True)
mues2bal.head()
# Out:
#    CUSTOMER_ID  std_pago_unired  max_pago_unired  avg_pago_unired  \
# 0      9097662      8457.780301            28450     11578.571429
# 1     12950772     45061.982246           238720    138554.846154
# 2     12950772     45061.982246           238720    138554.846154
# 3     12950772     45061.982246           238720    138554.846154
# 4     12950772     45061.982246           238720    138554.846154
#
#    pago_unired_mensual  avg_dia_pago_unired  max_dia_pago_unired  \
# 0                81050             4.371121             7.328028
# 1              1801213             3.352413             7.571878
# 2              1801213             3.352413             7.571878
# 3              1801213             3.352413             7.571878
# 4              1801213             3.352413             7.571878
#
#    min_dia_pago_unired  avg_uso_tarjeta  PAYMENT_MEAN_ID   ...    \
# 0             1.414214         0.000000                0   ...
# ...

# %%
mues2bal.columns
# Out:
# Index(['CUSTOMER_ID', 'std_pago_unired', 'max_pago_unired', 'avg_pago_unired',
#        'pago_unired_mensual', 'avg_dia_pago_unired', 'max_dia_pago_unired',
#        'min_dia_pago_unired', 'avg_uso_tarjeta', 'PAYMENT_MEAN_ID',
#        'avg_pago_retail_mensual', 'max_pago_retail_mensual',
#        'std_pago_retail_mensual', 'SPEND_AMT', 'DISCOUNT_AMT', 'GENDER',
#        'EDAD', 'MOBILE_CONTACTABILITY', 'EMAIL_CONTACTABILITY', 'GSE',
#        'CIVIL_STATUS', 'bloqueo'],
#       dtype='object')

# %% [markdown]
# ## PLOTEO DE LOS DATOS MUES2BAL

# %%
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
df = mues2bal

# %%
g = sns.FacetGrid(df, col="GENDER")
g.map(plt.hist, "SPEND_AMT")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GENDER")
g.map(plt.hist, "DISCOUNT_AMT")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GENDER")
g.map(plt.hist, "max_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GENDER")
g.map(plt.hist, "avg_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GENDER")
g.map(plt.hist, "pago_unired_mensual")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GENDER")
g.map(plt.hist, "max_dia_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GENDER")
g.map(plt.hist, "min_dia_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GENDER")
g.map(plt.hist, "avg_pago_retail_mensual")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GENDER")
g.map(plt.hist, "max_pago_retail_mensual")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GENDER")
g.map(plt.hist, "bloqueo")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GENDER")
g.map(plt.hist, "EDAD")
g.set_xticklabels(rotation=30)

# %% [markdown]
# ### GSE

# %%
g = sns.FacetGrid(df, col="GSE")
g.map(plt.hist, "SPEND_AMT")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GSE")
g.map(plt.hist, "DISCOUNT_AMT")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GSE")
g.map(plt.hist, "max_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GSE")
g.map(plt.hist, "avg_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GSE")
g.map(plt.hist, "pago_unired_mensual")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GSE")
g.map(plt.hist, "max_dia_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GSE")
g.map(plt.hist, "min_dia_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GSE")
g.map(plt.hist, "avg_pago_retail_mensual")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GSE")
g.map(plt.hist, "max_pago_retail_mensual")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GSE")
g.map(plt.hist, "bloqueo")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GSE")
g.map(plt.hist, "PAYMENT_MEAN_ID")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GSE")
g.map(plt.hist, "EDAD")
g.set_xticklabels(rotation=30)

# %% [markdown]
# ### BLOQUEO

# %%
g = sns.FacetGrid(df, col="bloqueo")
g.map(plt.hist, "SPEND_AMT")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="bloqueo")
g.map(plt.hist, "DISCOUNT_AMT")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="bloqueo")
g.map(plt.hist, "max_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="bloqueo")
g.map(plt.hist, "avg_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="bloqueo")
g.map(plt.hist, "pago_unired_mensual")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="bloqueo")
g.map(plt.hist, "max_dia_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="bloqueo")
g.map(plt.hist, "min_dia_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="bloqueo")
g.map(plt.hist, "avg_pago_retail_mensual")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="bloqueo")
g.map(plt.hist, "max_pago_retail_mensual")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="bloqueo")
g.map(plt.hist, "EDAD")
g.set_xticklabels(rotation=30)

# %% [markdown]
# ### MEDIO DE PAGO

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "SPEND_AMT")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "DISCOUNT_AMT")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "max_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "avg_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "pago_unired_mensual")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "max_dia_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "min_dia_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "avg_pago_retail_mensual")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "max_pago_retail_mensual")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "bloqueo")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "EDAD")
g.set_xticklabels(rotation=30)

# %% [markdown]
# ## PLOTEO DE LOS DATOS BLOQ2BAL

# %%
df = bloq2bal

# %% [markdown]
# ### BLOQUEO

# %%
g = sns.FacetGrid(df, col="bloqueo")
g.map(plt.hist, "SPEND_AMT", bins=10)
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="bloqueo")
g.map(plt.hist, "DISCOUNT_AMT", bins=10)
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="bloqueo")
g.map(plt.hist, "max_pago_unired", bins=10)
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="bloqueo")
g.map(plt.hist, "avg_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="bloqueo")
g.map(plt.hist, "pago_unired_mensual")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="bloqueo")
g.map(plt.hist, "max_dia_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="bloqueo")
g.map(plt.hist, "min_dia_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="bloqueo")
g.map(plt.hist, "avg_pago_retail_mensual")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="bloqueo")
g.map(plt.hist, "max_pago_retail_mensual")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="bloqueo")
g.map(plt.hist, "EDAD")
g.set_xticklabels(rotation=30)

# %% [markdown]
# ### MEDIO DE PAGO

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "SPEND_AMT")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "DISCOUNT_AMT")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "max_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "avg_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "pago_unired_mensual")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "max_dia_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "min_dia_pago_unired")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "avg_pago_retail_mensual")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "max_pago_retail_mensual")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "bloqueo")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="PAYMENT_MEAN_ID")
g.map(plt.hist, "EDAD")
g.set_xticklabels(rotation=30)

# %%
g = sns.FacetGrid(df, col="GENDER", hue="PAYMENT_MEAN_ID")
g.map(plt.scatter, "SPEND_AMT", "DISCOUNT_AMT", alpha=.7)
g.add_legend()
g.set_xticklabels(rotation=60)

# %%
g = sns.FacetGrid(df, col="GENDER", hue="bloqueo")
g.map(plt.scatter, "SPEND_AMT", "DISCOUNT_AMT", alpha=.7)
g.add_legend()
g.set_xticklabels(rotation=60)

# %%
g = sns.FacetGrid(df, col="GSE", hue="PAYMENT_MEAN_ID")
g.map(plt.scatter, "SPEND_AMT", "DISCOUNT_AMT", alpha=.7)
g.add_legend()
g.set_xticklabels(rotation=60)

# %%
g = sns.FacetGrid(df, col="GSE", hue="bloqueo")
g.map(plt.scatter, "SPEND_AMT", "DISCOUNT_AMT", alpha=.7)
g.add_legend()
g.set_xticklabels(rotation=60)

# %%
g = sns.FacetGrid(df, col="GENDER", hue="PAYMENT_MEAN_ID")
g.map(plt.scatter, "max_pago_unired", "max_pago_retail_mensual", alpha=.7)
g.add_legend()
g.set_xticklabels(rotation=60)

# %%
g = sns.FacetGrid(df, col="GENDER", hue="bloqueo")
g.map(plt.scatter, "max_pago_unired", "max_pago_retail_mensual", alpha=.7)
g.add_legend()
g.set_xticklabels(rotation=60)

# %%
g = sns.FacetGrid(df, col="GSE", hue="PAYMENT_MEAN_ID")
g.map(plt.scatter, "max_pago_unired", "max_pago_retail_mensual", alpha=.7)
g.add_legend()
g.set_xticklabels(rotation=60)

# %%
g = sns.FacetGrid(df, col="GSE", hue="bloqueo")
g.map(plt.scatter, "max_pago_unired", "max_pago_retail_mensual", alpha=.7)
g.add_legend()
g.set_xticklabels(rotation=60)

# %%
g = sns.FacetGrid(df, col="GENDER", hue="bloqueo")
g.map(plt.scatter, "max_pago_unired", "max_pago_retail_mensual", alpha=.7)
g.add_legend()
g.set_xticklabels(rotation=60)

# %%
g = sns.FacetGrid(df, col="GSE", hue="bloqueo")
g.map(plt.scatter, "max_pago_unired", "max_pago_retail_mensual", alpha=.7)
g.add_legend()
g.set_xticklabels(rotation=60)

# %%
g = sns.FacetGrid(df, col="GENDER", hue="bloqueo")
g.map(plt.scatter, "avg_pago_retail_mensual", "EDAD", alpha=.7)
g.add_legend()
g.set_xticklabels(rotation=60)

# %%
g = sns.FacetGrid(df, col="GSE", hue="bloqueo")
g.map(plt.scatter, "avg_pago_retail_mensual", "EDAD", alpha=.7)
g.add_legend()
g.set_xticklabels(rotation=60)

# %%
g = sns.FacetGrid(df, col="GENDER", hue="bloqueo")
g.map(plt.scatter, "avg_pago_retail_mensual", "EDAD", alpha=.7)
g.add_legend()
g.set_xticklabels(rotation=60)

# %%
g = sns.FacetGrid(df, col="GSE", hue="bloqueo")
g.map(plt.scatter, "avg_pago_retail_mensual", "EDAD", alpha=.7)
g.add_legend()
g.set_xticklabels(rotation=60)

# %%
g = sns.FacetGrid(df, col="GENDER", hue="PAYMENT_MEAN_ID")
g.map(plt.scatter, "max_pago_unired", "max_pago_retail_mensual", alpha=.7)
g.add_legend()
g.set_xticklabels(rotation=60)

# %%
g = sns.FacetGrid(df, col="GSE", hue="PAYMENT_MEAN_ID")
g.map(plt.scatter, "max_pago_unired", "max_pago_retail_mensual", alpha=.7)
g.add_legend()
g.set_xticklabels(rotation=60)

# %%
g = sns.FacetGrid(df, col="GENDER", hue="PAYMENT_MEAN_ID")
g.map(plt.scatter, "avg_pago_retail_mensual", "EDAD", alpha=.7)
g.add_legend()
g.set_xticklabels(rotation=60)

# %%
g = sns.FacetGrid(df, col="GSE", hue="PAYMENT_MEAN_ID")
g.map(plt.scatter, "avg_pago_retail_mensual", "EDAD", alpha=.7)
g.add_legend()
g.set_xticklabels(rotation=60)

# %%
g = sns.FacetGrid(df, col="GENDER", hue="PAYMENT_MEAN_ID")
g.map(plt.scatter, "avg_pago_retail_mensual", "EDAD", alpha=.7)
g.add_legend()
g.set_xticklabels(rotation=60)

# %%
g = sns.FacetGrid(df, col="GSE", hue="PAYMENT_MEAN_ID")
g.map(plt.scatter, "avg_pago_retail_mensual", "EDAD", alpha=.7)
g.add_legend()
g.set_xticklabels(rotation=60)

# %%
df.columns
# Out:
# Index(['CUSTOMER_ID', 'std_pago_unired', 'max_pago_unired', 'avg_pago_unired',
#        'pago_unired_mensual', 'avg_dia_pago_unired', 'max_dia_pago_unired',
#        'min_dia_pago_unired', 'avg_uso_tarjeta', 'PAYMENT_MEAN_ID',
#        'avg_pago_retail_mensual', 'max_pago_retail_mensual',
#        'std_pago_retail_mensual', 'SPEND_AMT', 'DISCOUNT_AMT', 'GENDER',
#        'EDAD', 'MOBILE_CONTACTABILITY', 'EMAIL_CONTACTABILITY', 'GSE',
#        'CIVIL_STATUS', 'bloqueo'],
#       dtype='object')

# %%
aux = df[df['bloqueo']==1]
aux['avg_pago_retail_mensual'].hist(bins=100)
aux['avg_pago_retail_mensual'].mean()
# Out:
# 44524.36786610886

# %%
aux2 = df[df['bloqueo']==0]
aux2['avg_pago_retail_mensual'].hist(bins=100)
aux2['avg_pago_retail_mensual'].mean()
# Out:
# 46464.184782913064
